# %%
import requests
import datetime
import json
from fake_useragent import UserAgent

# %%
temp_user_agent = UserAgent()
browser_header = {'User-Agent': temp_user_agent.random}

# %%
POST_CODE = "600073"
age = 52

# Print details flag
print_flag = 'Y'

numdays = 20

# %%
base = datetime.datetime.today()
date_list = [base + datetime.timedelta(days=x) for x in range(numdays)]
date_str = [x.strftime("%d-%m-%Y") for x in date_list]

# %%
for INP_DATE in date_str:
    URL = "https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/calendarByPin?pincode={}&date={}".format(POST_CODE, INP_DATE)
    response = requests.get(URL, headers=browser_header)
    if response.ok:
        resp_json = response.json()
        # print(json.dumps(resp_json, indent = 1))
        flag = False
        if resp_json["centers"]:
            print("Available on: {}".format(INP_DATE))
            if(print_flag=='y' or print_flag=='Y'):
                for center in resp_json["centers"]:
                    for session in center["sessions"]:
                        if session["min_age_limit"] <= age:
                            print("\t", center["name"])
                            print("\t", center["block_name"])
                            print("\t Price: ", center["fee_type"])
                            print("\t Available Capacity: ", session["available_capacity"])
                            if(session["vaccine"] != ''):
                                print("\t Vaccine: ", session["vaccine"])
                            print("\n\n")
                            
            
                
        else:
            print("No available slots on {}".format(INP_DATE))
# Out:
# Available on: 06-12-2021
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  388
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  398
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  400
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  399
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  390
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  398
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  400
# 	 Vaccine:  COVISHIELD
#
#
#
# Available on: 07-12-2021
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  398
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  400
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  399
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  390
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  398
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  400
# 	 Vaccine:  COVISHIELD
#
#
#
# Available on: 08-12-2021
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  400
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  399
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  390
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  398
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  400
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  399
# 	 Vaccine:  COVISHIELD
#
#
#
# Available on: 09-12-2021
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  399
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  390
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  398
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  400
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  399
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  398
# 	 Vaccine:  COVISHIELD
#
#
#
# Available on: 10-12-2021
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  390
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  398
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  400
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  399
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  398
# 	 Vaccine:  COVISHIELD
#
#
#
# Available on: 11-12-2021
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  398
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  400
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  399
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  398
# 	 Vaccine:  COVISHIELD
#
#
#
# Available on: 12-12-2021
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  400
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  399
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  398
# 	 Vaccine:  COVISHIELD
#
#
#
# Available on: 13-12-2021
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  399
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  398
# 	 Vaccine:  COVISHIELD
#
#
#
# Available on: 14-12-2021
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  399
# 	 Vaccine:  COVISHIELD
#
#
#
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  398
# 	 Vaccine:  COVISHIELD
#
#
#
# Available on: 15-12-2021
# 	 Bethesda Hospital.
# 	 St.Thomas Mount
# 	 Price:  Paid
# 	 Available Capacity:  398
# 	 Vaccine:  COVISHIELD
#
#
#
# No available slots on 16-12-2021
# No available slots on 17-12-2021
# No available slots on 18-12-2021
# No available slots on 19-12-2021
# No available slots on 20-12-2021
# No available slots on 21-12-2021
# No available slots on 22-12-2021
# No available slots on 23-12-2021
# No available slots on 24-12-2021
# No available slots on 25-12-2021

# %%
pip install htbuilder
# Out:
# Collecting htbuilder
#   Downloading htbuilder-0.5.0.tar.gz (11 kB)
# Collecting iteration_utilities
#   Downloading iteration_utilities-0.11.0-cp38-cp38-win_amd64.whl (89 kB)
# Building wheels for collected packages: htbuilder
#   Building wheel for htbuilder (setup.py): started
#   Building wheel for htbuilder (setup.py): finished with status 'done'
#   Created wheel for htbuilder: filename=htbuilder-0.5.0-py3-none-any.whl size=12454 sha256=2ea5157a7ebd5fc4658e55d60d6927b3cdd4289ccf08f4276dc135aa96f2229e
#   Stored in directory: c:\users\mailp\appdata\local\pip\cache\wheels\27\ea\97\525ca855fb15a744f6aea80008028e0afd27dde42c686f41a5
# Successfully built htbuilder
# Installing collected packages: iteration-utilities, htbuilder
# Successfully installed htbuilder-0.5.0 iteration-utilities-0.11.0
# Note: you may need to restart the kernel to use updated packages.
